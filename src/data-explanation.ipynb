# %%
# !pip install --upgrade nbformat plotly
# Out:
# Requirement already satisfied: nbformat in c:\users\mirel\anaconda3\lib\site-packages (5.9.2)
# Collecting nbformat
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: plotly in c:\users\mirel\anaconda3\lib\site-packages (5.9.0)
# Collecting plotly
#   Using cached plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\mirel\anaconda3\lib\site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mirel\anaconda3\lib\site-packages (from nbformat) (4.19.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mirel\anaconda3\lib\site-packages (from nbformat) (5.5.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\mirel\anaconda3\lib\site-packages (from nbformat) (5.7.1)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.27.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\mirel\anaconda3\lib\site-packages (from plotly) (23.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mirel\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\mirel\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (305.1)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached plotly-6.0.0-py3-none-any.whl (14.8 MB)
# Downloading narwhals-1.27.1-py3-none-any.whl (308 kB)
#    ---------------------------------------- 0.0/308.8 kB ? eta -:--:--
#    - -------------------------------------- 10.2/308.8 kB ? eta -:--:--
#    ------- ------------------------------- 61.4/308.8 kB 812.7 kB/s eta 0:00:01
#    ---------------------------------------  307.2/308.8 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 308.8/308.8 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: narwhals, plotly, nbformat
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Uninstalling plotly-5.9.0:
#       Successfully uninstalled plotly-5.9.0
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.9.2
#     Uninstalling nbformat-5.9.2:
#       Successfully uninstalled nbformat-5.9.2
# Successfully installed narwhals-1.27.1 nbformat-5.10.4 plotly-6.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires nbformat==5.9.2, but you have nbformat 5.10.4 which is incompatible.
# conda-repo-cli 1.0.75 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.

# %%
# !pip install matplotlib seaborn pandas numpy plotly geopandas nbformat==4.2.0
# Out:
# Requirement already satisfied: matplotlib in c:\users\mirel\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\users\mirel\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas in c:\users\mirel\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\mirel\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: plotly in c:\users\mirel\anaconda3\lib\site-packages (6.0.0)
# Collecting geopandas
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting nbformat==4.2.0
#   Using cached nbformat-4.2.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: ipython-genutils in c:\users\mirel\anaconda3\lib\site-packages (from nbformat==4.2.0) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\mirel\anaconda3\lib\site-packages (from nbformat==4.2.0) (4.19.2)
# Requirement already satisfied: jupyter-core in c:\users\mirel\anaconda3\lib\site-packages (from nbformat==4.2.0) (5.5.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\mirel\anaconda3\lib\site-packages (from nbformat==4.2.0) (5.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mirel\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mirel\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mirel\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\mirel\anaconda3\lib\site-packages (from plotly) (1.27.1)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.7-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mirel\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==4.2.0) (0.10.6)
# Requirement already satisfied: certifi in c:\users\mirel\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\mirel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mirel\anaconda3\lib\site-packages (from jupyter-core->nbformat==4.2.0) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\mirel\anaconda3\lib\site-packages (from jupyter-core->nbformat==4.2.0) (305.1)
# Using cached nbformat-4.2.0-py2.py3-none-any.whl (153 kB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading pyogrio-0.10.0-cp311-cp311-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.2 MB 2.2 MB/s eta 0:00:08
#     --------------------------------------- 0.3/16.2 MB 3.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/16.2 MB 3.4 MB/s eta 0:00:05
#    --- ------------------------------------ 1.4/16.2 MB 8.1 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.2 MB 15.4 MB/s eta 0:00:01
#    ------------ --------------------------- 5.1/16.2 MB 20.2 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/16.2 MB 26.1 MB/s eta 0:00:01
#    ------------------ --------------------- 7.4/16.2 MB 22.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/16.2 MB 25.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.1/16.2 MB 43.7 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.2 MB 46.9 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.2 MB 46.9 MB/s eta 0:00:01
#    ------------------------------------- -- 15.3/16.2 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 36.4 MB/s eta 0:00:00
# Downloading pyproj-3.7.1-cp311-cp311-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ----------------- ---------------------- 2.7/6.3 MB 86.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 75.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 57.5 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 44.8 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas, nbformat
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.10.4
#     Uninstalling nbformat-5.10.4:
#       Successfully uninstalled nbformat-5.10.4
# Successfully installed geopandas-1.0.1 nbformat-4.2.0 pyogrio-0.10.0 pyproj-3.7.1 shapely-2.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# anaconda-client 1.13.0 requires nbformat>=4.4.0, but you have nbformat 4.2.0 which is incompatible.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires nbformat==5.9.2, but you have nbformat 4.2.0 which is incompatible.
# conda-repo-cli 1.0.75 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# jupyter-server 2.10.0 requires nbformat>=5.3.0, but you have nbformat 4.2.0 which is incompatible.
# nbclient 0.8.0 requires nbformat>=5.1, but you have nbformat 4.2.0 which is incompatible.
# nbconvert 7.10.0 requires nbformat>=5.7, but you have nbformat 4.2.0 which is incompatible.

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import geopandas as gpd
import plotly.graph_objects as go
from datetime import datetime as dt

# %%
import tarfile

# Caminho do arquivo .tar.gz
tar_path = "../data/accidents_2017_to_2023.tar.gz"

# Abre o tar.gz
with tarfile.open(tar_path, "r:gz") as tar:
    # Lista os arquivos dentro do tar.gz
    for member in tar.getmembers():
        print(member.name)  # Mostra os nomes dos arquivos dentro do .tar.gz
        
        # Se encontrar o CSV, lê direto para um DataFrame
        if member.name.endswith(".csv"):
            with tar.extractfile(member) as file:
                df = pd.read_csv(file)
                print(df.head())  # Mostra as primeiras linhas do CSV
# Out:
# ./data
# ./data/accidents_2017_to_2023_portugues.csv
#   data_inversa dia_semana   horario  uf     br     km       municipio  \
# 0   2017-01-01    domingo  01:45:00  RS  116.0   34,9         VACARIA
# 1   2017-01-01    domingo  01:00:00  PR  376.0    636  TIJUCAS DO SUL
# 2   2017-01-01    domingo  04:40:00  BA  101.0     65      ENTRE RIOS
# 3   2017-01-01    domingo  06:30:00  PA  316.0   72,5       CASTANHAL
# 4   2017-01-01    domingo  09:00:00  GO   20.0  220,5           POSSE
#
#                 causa_acidente                tipo_acidente  \
# 0  Defeito Mecânico no Veículo             Colisão traseira
# 1      Velocidade Incompatível    Saída de leito carroçável
# 2            Condutor Dormindo              Colisão frontal
# 3  Falta de Atenção à Condução              Colisão lateral
# 4               Defeito na Via  Colisão com objeto estático
#
#   classificacao_acidente  ... feridos_leves feridos_graves ilesos ignorados  \
# 0    Com Vítimas Feridas  ...             4              0      2         0
# 1     Com Vítimas Fatais  ...             0              0      1         0
# 2     Com Vítimas Fatais  ...             1              1      2         0
# 3     Com Vítimas Fatais  ...             0              0      3         0
# 4    Com Vítimas Feridas  ...             2              1      0         0
#
#   feridos  veiculos  latitude  longitude  regional  delegacia
# 0       4         2 -28.50712  -50.94118   SPRF-RS   DEL05-RS
# 1       0         2 -25.75400  -49.12660   SPRF-PR   DEL01-PR
# 2       2         2 -11.96180  -38.09530   SPRF-BA   DEL01-BA
# 3       0         3  -1.28998  -47.83483   SPRF-PA   DEL01-PA
# 4       3         1 -14.14221  -46.32259   SPRF-DF   DEL02-DF
#
# [5 rows x 27 columns]

# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## 2 - Entendimento do conjuto de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463152 entries, 0 to 463151
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   data_inversa            463152 non-null  object
#  1   dia_semana              463152 non-null  object
#  2   horario                 463152 non-null  object
#  3   uf                      463152 non-null  object
#  4   br                      462162 non-null  float64
#  5   km                      462162 non-null  object
#  6   municipio               463152 non-null  object
#  7   causa_acidente          463152 non-null  object
#  8   tipo_acidente           463112 non-null  object
#  9   classificacao_acidente  463152 non-null  object
#  10  fase_dia                463152 non-null  object
#  11  sentido_via             463152 non-null  object
#  12  condicao_metereologica  463152 non-null  object
#  13  tipo_pista              463152 non-null  object
#  14  tracado_via             463152 non-null  object
#  15  pessoas                 463152 non-null  int64
#  16  mortos                  463152 non-null  int64
#  17  feridos_leves           463152 non-null  int64
#  18  feridos_graves          463152 non-null  int64
#  19  ilesos                  463152 non-null  int64
#  20  ignorados               463152 non-null  int64
#  21  feridos                 463152 non-null  int64
#  22  veiculos                463152 non-null  int64
#  23  latitude                463152 non-null  float64
#  24  longitude               463152 non-null  float64
#  25  regional                463142 non-null  object
#  26  delegacia               461842 non-null  object
# dtypes: float64(3), int64(8), object(16)
# memory usage: 95.4+ MB

# %%
df.describe()
# Out:
#                   br        pessoas         mortos  feridos_leves  \
# count  462162.000000  463152.000000  463152.000000  463152.000000
# mean      213.432900       2.362373       0.079235       0.835469
# std       130.757607       1.924801       0.332169       1.075275
# min        10.000000       1.000000       0.000000       0.000000
# 25%       101.000000       1.000000       0.000000       0.000000
# 50%       163.000000       2.000000       0.000000       1.000000
# 75%       324.000000       3.000000       0.000000       1.000000
# max       498.000000      80.000000      21.000000      61.000000
#
#        feridos_graves         ilesos      ignorados        feridos  \
# count   463152.000000  463152.000000  463152.000000  463152.000000
# mean         0.259530       1.044070       0.144069       1.094999
# std          0.602814       1.502419       0.438168       1.205351
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.000000       0.000000       0.000000       0.000000
# 50%          0.000000       1.000000       0.000000       1.000000
# 75%          0.000000       1.000000       0.000000       1.000000
# max         31.000000      73.000000      54.000000      66.000000
#
#             veiculos      latitude     longitude
# count  463152.000000  4.631520e+05  4.631520e+05
# mean        1.645725 -2.343287e+03 -8.924977e+03
# std         0.731394  1.519113e+06  5.903043e+06
# min         1.000000 -1.033383e+09 -4.016764e+09
# 25%         1.000000 -2.533123e+01 -5.030294e+01
# 50%         2.000000 -2.042034e+01 -4.780831e+01
# 75%         2.000000 -1.282657e+01 -4.264249e+01
# max        23.000000  1.630000e+02  7.170000e+02

# %% [markdown]
# ## 3 - Limpeza e Transformação dos Dados

# %%
# Convertendo as coluna da data dos acidentes (data_inversa) e horario para o formato data
df['data_acidente']= pd.to_datetime(df['data_inversa'] + df['horario'], format='%Y-%m-%d%H:%M:%S')
# Excluindo colunas desnecessárias
df = df.drop(columns=['delegacia', 'regional', 'data_inversa'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463152 entries, 0 to 463151
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   dia_semana              463152 non-null  object
#  1   horario                 463152 non-null  object
#  2   uf                      463152 non-null  object
#  3   br                      462162 non-null  float64
#  4   km                      462162 non-null  object
#  5   municipio               463152 non-null  object
#  6   causa_acidente          463152 non-null  object
#  7   tipo_acidente           463112 non-null  object
#  8   classificacao_acidente  463152 non-null  object
#  9   fase_dia                463152 non-null  object
#  10  sentido_via             463152 non-null  object
#  11  condicao_metereologica  463152 non-null  object
#  12  tipo_pista              463152 non-null  object
#  13  tracado_via             463152 non-null  object
#  14  pessoas                 463152 non-null  int64
#  15  mortos                  463152 non-null  int64
#  16  feridos_leves           463152 non-null  int64
#  17  feridos_graves          463152 non-null  int64
#  18  ilesos                  463152 non-null  int64
#  19  ignorados               463152 non-null  int64
#  20  feridos                 463152 non-null  int64
#  21  veiculos                463152 non-null  int64
#  22  latitude                463152 non-null  float64
#  23  longitude               463152 non-null  float64
#  24  data_acidente           463152 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(8), object(13)
# memory usage: 88.3+ MB

# %%
# Alterando , por . na coluna km para que os valores sejam compreendidos como float
df['km'] = df['km'].str.replace(',', '.').astype(float)

# %%
# Encontrando duplicatas
df.duplicated().sum()
# Out:
# 9

# %%
# Visualizar as duplicatas
duplicatas = df[df.duplicated(keep=False)]
duplicatas.head(20)
# Out:
#            dia_semana   horario  uf     br     km           municipio  \
# 19243     sexta-feira  14:25:00  SC  282.0  483.9  FAXINAL DOS GUEDES
# 75470     sexta-feira  14:25:00  SC  282.0  483.9  FAXINAL DOS GUEDES
# 79108          sábado  17:00:00  GO   60.0  201.8               GUAPO
# 79109          sábado  17:00:00  GO   60.0  201.8               GUAPO
# 80504         domingo  15:40:00  RJ   40.0  113.0     DUQUE DE CAXIAS
# 80505         domingo  15:40:00  RJ   40.0  113.0     DUQUE DE CAXIAS
# 353536   quinta-feira  17:30:00  SC  101.0  135.3  BALNEARIO CAMBORIU
# 354092   quinta-feira  17:30:00  SC  101.0  135.3  BALNEARIO CAMBORIU
# 381910   quarta-feira  20:19:00  GO   50.0  263.5             CATALAO
# 381911   quarta-feira  20:19:00  GO   50.0  263.5             CATALAO
# 388012        domingo  17:00:00  AM  174.0  914.0              MANAUS
# 389230   quarta-feira  15:32:00  AM  174.0  888.0              MANAUS
# 394433   quarta-feira  15:32:00  AM  174.0  888.0              MANAUS
# 394944        domingo  17:00:00  AM  174.0  914.0              MANAUS
# 406026   quinta-feira  22:15:00  RJ  356.0  167.0   SAO JOAO DA BARRA
# 418030   quinta-feira  22:15:00  RJ  356.0  167.0   SAO JOAO DA BARRA
# 418744  segunda-feira  19:50:00  RS  116.0  250.0        SAO LEOPOLDO
# 419094  segunda-feira  19:50:00  RS  116.0  250.0        SAO LEOPOLDO
#
#                                            causa_acidente  \
# 19243                  Não guardar distância de segurança
# 75470                  Não guardar distância de segurança
# 79108                                  Pista Escorregadia
# 79109                                  Pista Escorregadia
# 80504                                      Defeito na Via
# 80505                                      Defeito na Via
# 353536  Acessar a via sem observar a presença dos outr...
# 354092  Acessar a via sem observar a presença dos outr...
# 381910           Reação tardia ou ineficiente do condutor
# 381911           Reação tardia ou ineficiente do condutor
# 388012                     Ausência de reação do condutor
# 389230                     Ausência de reação do condutor
# 394433                     Ausência de reação do condutor
# 394944                     Ausência de reação do condutor
# 406026                            Condutor usando celular
# 418030                            Condutor usando celular
# 418744           Objeto estático sobre o leito carroçável
# 419094           Objeto estático sobre o leito carroçável
#
#                          tipo_acidente classificacao_acidente     fase_dia  \
# 19243                 Colisão traseira            Sem Vítimas    Pleno dia
# 75470                 Colisão traseira            Sem Vítimas    Pleno dia
# 79108      Colisão com objeto estático            Sem Vítimas    Pleno dia
# 79109      Colisão com objeto estático            Sem Vítimas    Pleno dia
# 80504                 Colisão traseira    Com Vítimas Feridas    Pleno dia
# 80505                 Colisão traseira    Com Vítimas Feridas    Pleno dia
# 353536                 Colisão frontal    Com Vítimas Feridas    Pleno dia
# 354092                 Colisão frontal    Com Vítimas Feridas    Pleno dia
# 381910                      Tombamento    Com Vítimas Feridas  Plena Noite
# 381911                      Tombamento    Com Vítimas Feridas  Plena Noite
# 388012                Colisão traseira            Sem Vítimas    Pleno dia
# 389230                Colisão traseira            Sem Vítimas    Pleno dia
# 394433                Colisão traseira            Sem Vítimas    Pleno dia
# 394944                Colisão traseira            Sem Vítimas    Pleno dia
# 406026  Colisão lateral sentido oposto    Com Vítimas Feridas  Plena Noite
# 418030  Colisão lateral sentido oposto    Com Vítimas Feridas  Plena Noite
# 418744              Colisão com objeto    Com Vítimas Feridas  Plena Noite
# 419094              Colisão com objeto    Com Vítimas Feridas  Plena Noite
#
#         ... mortos feridos_leves feridos_graves ilesos  ignorados  feridos  \
# 19243   ...      0             0              0      2          0        0
# 75470   ...      0             0              0      2          0        0
# 79108   ...      0             0              0      1          0        0
# 79109   ...      0             0              0      1          0        0
# 80504   ...      0             1              0      2          0        1
# 80505   ...      0             1              0      2          0        1
# 353536  ...      0             1              0      1          0        1
# 354092  ...      0             1              0      1          0        1
# 381910  ...      0             1              0      0          0        1
# 381911  ...      0             1              0      0          0        1
# 388012  ...      0             0              0      3          0        0
# 389230  ...      0             0              0      5          0        0
# 394433  ...      0             0              0      5          0        0
# 394944  ...      0             0              0      3          0        0
# 406026  ...      0             1              1      2          0        2
# 418030  ...      0             1              1      2          0        2
# 418744  ...      0             2              0      3          0        2
# 419094  ...      0             2              0      3          0        2
#
#         veiculos   latitude  longitude       data_acidente
# 19243          2 -26.856710  -52.24642 2017-10-20 14:25:00
# 75470          2 -26.856710  -52.24642 2017-10-20 14:25:00
# 79108          1 -16.886220  -49.62302 2017-11-11 17:00:00
# 79109          1 -16.886220  -49.62302 2017-11-11 17:00:00
# 80504          2 -22.719200  -43.28960 2017-11-19 15:40:00
# 80505          2 -22.719200  -43.28960 2017-11-19 15:40:00
# 353536         2 -27.005010  -48.62677 2021-12-16 17:30:00
# 354092         2 -27.005010  -48.62677 2021-12-16 17:30:00
# 381910         1 -18.052100  -47.86300 2022-03-30 20:19:00
# 381911         1 -18.052100  -47.86300 2022-03-30 20:19:00
# 388012         2  -2.708225  -60.04866 2022-05-15 17:00:00
# 389230         2  -2.942329  -60.03368 2022-05-25 15:32:00
# 394433         2  -2.942329  -60.03368 2022-05-25 15:32:00
# 394944         2  -2.708225  -60.04866 2022-05-15 17:00:00
# 406026         2 -21.718560  -41.10128 2022-09-29 22:15:00
# 418030         2 -21.718560  -41.10128 2022-09-29 22:15:00
# 418744         2 -29.791490  -51.16400 2022-10-24 19:50:00
# 419094         2 -29.791490  -51.16400 2022-10-24 19:50:00
#
# [18 rows x 25 columns]

# %%
# Removendo dados duplicados
df.drop_duplicates(inplace=True)

# %%
# Criando um segundo dataframe somente com os dados de Pernambuco
df_pe = df[df['uf']=='PE']
df_pe.head()
# Out:
#        dia_semana   horario  uf     br     km    municipio  \
# 15        domingo  15:55:00  PE  101.0   62.8       RECIFE
# 24        domingo  22:00:00  PE  232.0  142.0  SAO CAITANO
# 25        domingo  21:30:00  PE  232.0   84.7      GRAVATA
# 34  segunda-feira  06:30:00  PE  101.0   23.0       GOIANA
# 51  segunda-feira  13:50:00  PE  101.0   73.2       RECIFE
#
#                   causa_acidente              tipo_acidente  \
# 15  Falta de Atenção do Pedestre  Atropelamento de Pedestre
# 24   Falta de Atenção à Condução            Colisão lateral
# 25              Animais na Pista    Atropelamento de Animal
# 34   Falta de Atenção à Condução           Colisão traseira
# 51   Falta de Atenção à Condução            Colisão lateral
#
#    classificacao_acidente     fase_dia  ... mortos feridos_leves  \
# 15    Com Vítimas Feridas    Pleno dia  ...      0             0
# 24            Sem Vítimas  Plena Noite  ...      0             0
# 25            Sem Vítimas  Plena Noite  ...      0             0
# 34            Sem Vítimas    Pleno dia  ...      0             0
# 51            Sem Vítimas    Pleno dia  ...      0             0
#
#    feridos_graves ilesos  ignorados  feridos  veiculos  latitude  longitude  \
# 15              1      1          1        1         1 -8.007427  -34.93785
# 24              0      2          0        0         2 -8.326607  -36.11564
# 25              0      1          0        0         1 -8.215031  -35.63572
# 34              0      2          0        0         2 -7.684500  -34.92370
# 51              0      3          0        0         2 -8.096529  -34.94960
#
#          data_acidente
# 15 2017-01-01 15:55:00
# 24 2017-01-01 22:00:00
# 25 2017-01-01 21:30:00
# 34 2017-01-02 06:30:00
# 51 2017-01-02 13:50:00
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 4 - Análise de Outliers

# %% [markdown]
# ### Brasil

# %%
df.describe()
# Out:
#                   br             km        pessoas         mortos  \
# count  462153.000000  462153.000000  463143.000000  463143.000000
# mean      213.434129     261.391031       2.362363       0.079237
# min        10.000000       0.000000       1.000000       0.000000
# 25%       101.000000      78.000000       1.000000       0.000000
# 50%       163.000000     196.000000       2.000000       0.000000
# 75%       324.000000     410.800000       3.000000       0.000000
# max       498.000000    1454.500000      80.000000      21.000000
# std       130.757799     227.456420       1.924808       0.332172
#
#        feridos_leves  feridos_graves         ilesos      ignorados  \
# count  463143.000000   463143.000000  463143.000000  463143.000000
# mean        0.835472        0.259533       1.044049       0.144072
# min         0.000000        0.000000       0.000000       0.000000
# 25%         0.000000        0.000000       0.000000       0.000000
# 50%         1.000000        0.000000       1.000000       0.000000
# 75%         1.000000        0.000000       1.000000       0.000000
# max        61.000000       31.000000      73.000000      54.000000
# std         1.075282        0.602818       1.502414       0.438172
#
#              feridos       veiculos      latitude     longitude  \
# count  463143.000000  463143.000000  4.631430e+05  4.631430e+05
# mean        1.095005       1.645723 -2.343332e+03 -8.925150e+03
# min         0.000000       1.000000 -1.033383e+09 -4.016764e+09
# 25%         0.000000       1.000000 -2.533118e+01 -5.030294e+01
# 50%         1.000000       2.000000 -2.042032e+01 -4.780831e+01
# 75%         1.000000       2.000000 -1.282657e+01 -4.264234e+01
# max        66.000000      23.000000  1.630000e+02  7.170000e+02
# std         1.205357       0.731398  1.519128e+06  5.903100e+06
#
#                        data_acidente
# count                         463143
# mean   2020-03-02 14:24:25.126407936
# min              2017-01-01 00:00:00
# 25%              2018-05-05 19:50:00
# 50%              2020-01-29 14:45:00
# 75%              2021-11-22 19:30:00
# max              2023-08-31 23:59:00
# std                              NaN

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5), tight_layout=True)

ax[0].boxplot(df['latitude'])
ax[0].set_title('Boxplot da coluna latitude')

ax[1].boxplot(df['longitude'])
ax[1].set_title('Boxplot da coluna longitude')

plt.show()

# %%
# Encontrando outliers, considerando os valores máximos e mínimos possíveis de latitude (-90 a 90) e longitude (-180 a 180)
df[(df['latitude']<-90) | (df['latitude']>90) | (df['longitude']<-180) | (df['longitude']>180)]
# Out:
#           dia_semana   horario  uf     br     km                  municipio  \
# 114      terça-feira  19:00:00  MG  381.0  873.0                     ESTIVA
# 117      terça-feira  18:50:00  RJ   40.0   64.0                 PETROPOLIS
# 166      terça-feira  13:00:00  BA  101.0  323.4  PRESIDENTE TANCREDO NEVES
# 233     quinta-feira  19:45:00  SC  101.0   40.7                  JOINVILLE
# 301      sexta-feira  20:40:00  MT  364.0  315.7                CAMPO VERDE
# 321           sábado  09:20:00  SP  116.0  292.0       ITAPECERICA DA SERRA
# 355           sábado  22:25:00  PR  277.0   36.3                   MORRETES
# 528     quarta-feira  09:00:00  PR  369.0  175.5                   ROLANDIA
# 24667        domingo  00:00:00  PR  153.0   56.9   SANTO ANTONIO DA PLATINA
# 24729        domingo  08:00:00  MT  163.0  790.0                       VERA
# 24775        domingo  13:50:00  TO    NaN    NaN                     GUARAI
# 24786        domingo  16:20:00  MG  381.0  442.9                     SABARA
# 24813        domingo  16:00:00  MT  163.0  717.0                    SORRISO
# 24875        domingo  21:20:00  PR  277.0  729.0              FOZ DO IGUACU
# 24921  segunda-feira  06:50:00  RJ   40.0  122.0            DUQUE DE CAXIAS
# 24971  segunda-feira  10:30:00  BA  407.0  111.0                  JAGUARARI
# 24985  segunda-feira  11:40:00  MG   50.0  147.3                   ARAGUARI
# 25069  segunda-feira  21:25:00  GO  153.0  196.1                     URUACU
# 25182    terça-feira  16:45:00  PR  277.0  429.4                    VIRMOND
# 25320        domingo  01:50:00  SC  101.0  132.0         BALNEARIO CAMBORIU
# 25329   quarta-feira  16:30:00  SC  101.0  149.0                    ITAPEMA
# 25336   quarta-feira  16:45:00  MG  116.0  275.0              TEOFILO OTONI
# 25337   quarta-feira  16:40:00  MG  381.0  936.1                    EXTREMA
# 25360   quarta-feira  19:00:00  SP  153.0   71.9      SAO JOSE DO RIO PRETO
# 25833         sábado  17:40:00  SC  470.0  116.5                    IBIRAMA
# 25931        domingo  01:15:00  PR  476.0  118.6                    COLOMBO
# 25975        domingo  04:00:00  RJ  101.0  531.0             ANGRA DOS REIS
# 26115        domingo  22:00:00  SP  116.0  109.5                    TAUBATE
# 26157  segunda-feira  05:30:00  PR  277.0  588.0                   CASCAVEL
# 26343    terça-feira  08:50:00  MT  174.0  467.0                   COMODORO
# 26483   quarta-feira  13:30:00  RS  386.0  100.2       SAO JOSE DAS MISSOES
# 31119   quinta-feira  16:00:00  RJ  101.0  463.8             ANGRA DOS REIS
# 43871    sexta-feira  16:20:00  MG  381.0  590.0        CARMOPOLIS DE MINAS
#
#                                 causa_acidente  \
# 114                         Pista Escorregadia
# 117                      Fenômenos da Natureza
# 166                     Ultrapassagem Indevida
# 233                Falta de Atenção à Condução
# 301                     Ultrapassagem Indevida
# 321                    Velocidade Incompatível
# 355                Falta de Atenção à Condução
# 528                          Condutor Dormindo
# 24667                         Animais na Pista
# 24729                  Velocidade Incompatível
# 24775              Falta de Atenção à Condução
# 24786                  Velocidade Incompatível
# 24813                       Ingestão de Álcool
# 24875       Não guardar distância de segurança
# 24921              Falta de Atenção à Condução
# 24971       Não guardar distância de segurança
# 24985                  Velocidade Incompatível
# 25069                       Ingestão de Álcool
# 25182              Falta de Atenção à Condução
# 25320              Falta de Atenção à Condução
# 25329                   Ultrapassagem Indevida
# 25336              Falta de Atenção à Condução
# 25337                  Velocidade Incompatível
# 25360              Falta de Atenção à Condução
# 25833                       Ingestão de Álcool
# 25931                  Velocidade Incompatível
# 25975                   Ultrapassagem Indevida
# 26115              Defeito Mecânico no Veículo
# 26157  Avarias e/ou desgaste excessivo no pneu
# 26343                       Pista Escorregadia
# 26483                  Velocidade Incompatível
# 31119                  Velocidade Incompatível
# 43871                               Mal Súbito
#
#                          tipo_acidente classificacao_acidente     fase_dia  \
# 114                         Tombamento            Sem Vítimas    Pleno dia
# 117    Colisão com objeto em movimento    Com Vítimas Feridas  Plena Noite
# 166                    Colisão lateral    Com Vítimas Feridas    Pleno dia
# 233          Saída de leito carroçável            Sem Vítimas  Plena Noite
# 301                    Colisão lateral            Sem Vítimas  Plena Noite
# 321                        Capotamento            Sem Vítimas    Pleno dia
# 355                   Colisão traseira            Sem Vítimas  Plena Noite
# 528        Colisão com objeto estático            Sem Vítimas    Pleno dia
# 24667                      Capotamento    Com Vítimas Feridas  Plena Noite
# 24729        Saída de leito carroçável            Sem Vítimas    Amanhecer
# 24775        Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 24786                  Colisão frontal    Com Vítimas Feridas    Pleno dia
# 24813        Saída de leito carroçável            Sem Vítimas    Pleno dia
# 24875                 Colisão traseira    Com Vítimas Feridas  Plena Noite
# 24921                  Colisão lateral    Com Vítimas Feridas    Pleno dia
# 24971                    Engavetamento            Sem Vítimas    Pleno dia
# 24985                  Colisão lateral    Com Vítimas Feridas    Pleno dia
# 25069        Saída de leito carroçável            Sem Vítimas  Plena Noite
# 25182      Colisão com objeto estático    Com Vítimas Feridas    Pleno dia
# 25320                 Colisão traseira            Sem Vítimas  Plena Noite
# 25329              Colisão transversal    Com Vítimas Feridas    Pleno dia
# 25336                 Colisão traseira    Com Vítimas Feridas    Pleno dia
# 25337      Colisão com objeto estático            Sem Vítimas    Pleno dia
# 25360              Colisão transversal    Com Vítimas Feridas    Pleno dia
# 25833                  Colisão frontal            Sem Vítimas    Pleno dia
# 25931        Saída de leito carroçável    Com Vítimas Feridas  Plena Noite
# 25975                  Colisão frontal    Com Vítimas Feridas    Amanhecer
# 26115                       Tombamento    Com Vítimas Feridas  Plena Noite
# 26157     Queda de ocupante de veículo    Com Vítimas Feridas  Plena Noite
# 26343        Saída de leito carroçável            Sem Vítimas    Pleno dia
# 26483        Saída de leito carroçável            Sem Vítimas    Pleno dia
# 31119        Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 43871                 Colisão traseira    Com Vítimas Feridas    Pleno dia
#
#        ... mortos feridos_leves feridos_graves ilesos  ignorados  feridos  \
# 114    ...      0             0              0      1          0        0
# 117    ...      0             0              1      1          0        1
# 166    ...      0             0              2      0          0        2
# 233    ...      0             0              0      1          0        0
# 301    ...      0             0              0      4          0        0
# 321    ...      0             0              0      2          0        0
# 355    ...      0             0              0      2          0        0
# 528    ...      0             0              0      2          0        0
# 24667  ...      0             2              0      0          0        2
# 24729  ...      0             0              0      0          1        0
# 24775  ...      0             1              0      0          0        1
# 24786  ...      0             0              1      1          0        1
# 24813  ...      0             0              0      1          0        0
# 24875  ...      0             1              0      2          0        1
# 24921  ...      0             1              0      1          1        1
# 24971  ...      0             0              0      3          0        0
# 24985  ...      0             0              1      1          0        1
# 25069  ...      0             0              0      1          0        0
# 25182  ...      0             1              0      0          0        1
# 25320  ...      0             0              0      2          0        0
# 25329  ...      0             1              0      1          0        1
# 25336  ...      0             1              0      1          0        1
# 25337  ...      0             0              0      1          0        0
# 25360  ...      0             2              1      0          0        3
# 25833  ...      0             0              0      2          0        0
# 25931  ...      0             1              0      0          0        1
# 25975  ...      0             0              1      1          0        1
# 26115  ...      0             2              0      0          0        2
# 26157  ...      0             2              0      0          0        2
# 26343  ...      0             0              0      1          1        0
# 26483  ...      0             0              0      2          0        0
# 31119  ...      0             0              2      0          0        2
# 43871  ...      0             0              1      2          0        1
#
#        veiculos      latitude     longitude       data_acidente
# 114           1 -2.241851e+01 -4.059646e+02 2017-01-03 19:00:00
# 117           1 -2.242356e+01 -7.631568e+02 2017-01-03 18:50:00
# 166           2  1.255456e+01 -4.113281e+02 2017-01-03 13:00:00
# 233           1 -2.631464e+01  3.111264e+02 2017-01-05 19:45:00
# 301           4  1.580000e+02  5.530000e+02 2017-01-06 20:40:00
# 321           2 -2.373232e+01 -4.068950e+02 2017-01-07 09:20:00
# 355           2 -2.557372e+01 -4.088183e+02 2017-01-07 22:25:00
# 528           2 -2.332490e+07 -5.138635e+07 2017-01-11 09:00:00
# 24667         1 -2.336952e+01  3.099351e+02 2017-01-01 00:00:00
# 24729         1 -1.227493e+01 -4.155582e+02 2017-01-01 08:00:00
# 24775         1 -8.844694e+00 -4.085105e+02 2017-01-01 13:50:00
# 24786         2 -1.984326e+07 -4.386112e+07 2017-01-01 16:20:00
# 24813         1  1.630000e+02  7.170000e+02 2017-01-01 16:00:00
# 24875         2 -2.545924e+01 -4.145838e+02 2017-01-01 21:20:00
# 24921         3 -2.279184e+01 -4.032867e+02 2017-01-02 06:50:00
# 24971         3 -1.033383e+09 -4.016764e+09 2017-01-02 10:30:00
# 24985         2 -1.873210e+01 -4.082120e+02 2017-01-02 11:40:00
# 25069         1 -1.449151e+01 -4.091529e+02 2017-01-02 21:25:00
# 25182         1 -2.537910e+01 -4.121934e+02 2017-01-03 16:45:00
# 25320         2 -2.699686e+01 -4.086545e+02 2017-01-01 01:50:00
# 25329         2 -2.711374e+01  3.113899e+02 2017-01-04 16:30:00
# 25336         2 -1.783965e+01 -4.015131e+02 2017-01-04 16:45:00
# 25337         1 -2.280858e+01  3.137211e+02 2017-01-04 16:40:00
# 25360         2 -2.087002e+01  3.105846e+02 2017-01-04 19:00:00
# 25833         2 -2.708020e+01  3.105144e+02 2017-01-07 17:40:00
# 25931         1 -2.535006e+01 -4.091655e+02 2017-01-08 01:15:00
# 25975         2  1.822381e+01 -8.247656e+02 2017-01-01 04:00:00
# 26115         1 -2.303114e+01 -4.055485e+02 2017-01-08 22:00:00
# 26157         1 -2.497813e+01 -7.734477e+02 2017-01-09 05:30:00
# 26343         1 -1.371439e+01 -4.197849e+02 2017-01-10 08:50:00
# 26483         1 -2.776015e+01 -4.131115e+02 2017-01-11 13:30:00
# 31119         1 -8.437157e+01 -5.182910e+02 2017-01-05 16:00:00
# 43871         2 -2.054570e+01  3.153494e+02 2017-01-06 16:20:00
#
# [33 rows x 25 columns]

# %% [markdown]
# Identificamos os valores acima como outliers. Porém ao verificar os dados das demais colunas, vimos que os outliers estavam apenas nas colunas de latitude e longitude, sendo provavelmente um erro de digitação. Pensamos em alterar apenas esses dados, mas decimos não fazer alterações, considerando que a princípio não utilizaremos essas colunas então retirar os registros completos não faz sentido.

# %% [markdown]
# ### Pernambuco

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5), tight_layout=True)

ax[0].boxplot(df_pe['latitude'])
ax[0].set_title('Boxplot da coluna latitude')

ax[1].boxplot(df_pe['longitude'])
ax[1].set_title('Boxplot da coluna longitude')

plt.show()

# %%
# Os valores de latitude e Longitude de Pernambuco estão dentro do intervalo esperado
df_pe[(df_pe['latitude']<-13) | (df_pe['latitude']>-7.4)]
# Out:
#       dia_semana   horario  uf     br     km municipio  \
# 372      domingo  11:00:00  PE  101.0   60.0    RECIFE
# 24825    domingo  17:40:00  PE  101.0  144.0  RIBEIRAO
# 24877    domingo  21:10:00  PE  101.0   59.0    RECIFE
# 25910     sábado  23:35:00  PE  316.0   91.0  OURICURI
#
#                            causa_acidente                 tipo_acidente  \
# 372    Não guardar distância de segurança              Colisão traseira
# 24825             Velocidade Incompatível  Queda de ocupante de veículo
# 24877  Não guardar distância de segurança              Colisão traseira
# 25910        Falta de Atenção do Pedestre     Atropelamento de Pedestre
#
#       classificacao_acidente     fase_dia  ... mortos feridos_leves  \
# 372              Sem Vítimas    Pleno dia  ...      0             0
# 24825    Com Vítimas Feridas    Anoitecer  ...      0             2
# 24877            Sem Vítimas  Plena Noite  ...      0             0
# 25910     Com Vítimas Fatais  Plena Noite  ...      1             0
#
#       feridos_graves ilesos  ignorados  feridos  veiculos  latitude  \
# 372                0      2          0        0         2 -15.00000
# 24825              0      0          0        2         1 -19.31114
# 24877              0     20          0        0         5  -7.00000
# 25910              0      1          0        0         1   7.90890
#
#        longitude       data_acidente
# 372    -47.00000 2017-01-08 11:00:00
# 24825  -34.74426 2017-01-01 17:40:00
# 24877  -34.00000 2017-01-01 21:10:00
# 25910   40.01630 2017-01-07 23:35:00
#
# [4 rows x 25 columns]

# %%
df_pe.drop([372, 24825, 24877, 25910], axis=0, inplace = True)
df_pe[(df_pe['latitude']<-13) | (df_pe['latitude']>-7.4)]
# Out:
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\2128232510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pe.drop([372, 24825, 24877, 25910], axis=0, inplace = True)
# Empty DataFrame
# Columns: [dia_semana, horario, uf, br, km, municipio, causa_acidente, tipo_acidente, classificacao_acidente, fase_dia, sentido_via, condicao_metereologica, tipo_pista, tracado_via, pessoas, mortos, feridos_leves, feridos_graves, ilesos, ignorados, feridos, veiculos, latitude, longitude, data_acidente]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# No caso dos outliers do banco de dados de Pernambuco, decidimos por apagar os registros com outliers, pois utilizamos os dados de latitude e longitude para gerar visualizações gráficas dos acidentes e mortes nas estradas e a presença dos outliers estava culminando em imagens incorretas.

# %%
imagem = '../utils/bcim_2016_21_11_2018.gpkg'

# %%
# Gráfico do Número de acidentes por Estado
df_acidentes = df[['uf', 'data_acidente']].groupby(by=df['uf']).agg({'data_acidente': 'count'}).sort_values(by='data_acidente', ascending=False)
df_mortes = df[['uf', 'mortos']].groupby(by=df['uf']).agg({'mortos': 'sum'}).sort_values(by='mortos', ascending=False)


fig, ax = plt.subplots(figsize=(15,10))
cores2 = ['gray' if uf != 'PE' else 'green' for uf in df_acidentes.index]
ax.bar(df_acidentes.index, df_acidentes['data_acidente'], color=cores2)
ax.set_title('Acidentes por estados', loc='left')
ax.set_xticklabels(ax.get_xticklabels(),rotation=0)

import matplotlib.patches as patches
rect = patches.Rectangle(
    xy=(-0.5, 0),  # Coordenada inferior esquerda (x, y)
    width=3,  # Largura do retângulo
    height=df_acidentes['data_acidente'].max() * 1.02,  # Altura do retângulo
    linewidth=2,  # Espessura da linha
    edgecolor='red',  # Cor do contorno
    facecolor='none'  # Sem preenchimento interno
)

# Adicionar o retângulo ao gráfico
ax.add_patch(rect)

ax.annotate(
    xy = (2.5,55000),
    text="Os 3 estados com mais acidentes são \nMinas Gerais, Santa Catarina e Paraná",  # Texto da anotação
    arrowprops=dict(facecolor='red', edgecolor='red', shrink=0.05), xytext=(5, 54500)
)

plt.show()
# Out:
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\3203777977.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=0)

# %% [markdown]
# # Análise Explanatória

# %% [markdown]
# ## Insight 1 - Principais causas dos acidentes nos estados com mais mortes

# %%
# Definição das cores para os três primeiros estados e cinza para os demais
cores_personalizadas = ["#8B0000", "#D72638", "#F46036"]  # Cores corrigidas
cores = [cores_personalizadas[i] if i < 3 else "gray" for i in range(len(df_mortes))]

# Criar a figura e o eixo
fig, ax = plt.subplots(figsize=(15, 10))

# Plotar o gráfico de barras com as cores ajustadas
ax.bar(df_mortes.index, df_mortes['mortos'], color=cores)

# Configurações do título e eixos
ax.set_title('Mortes em Acidentes por Estado', loc='left')
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)

# Adicionar um retângulo de destaque nos três primeiros estados
rect = patches.Rectangle(
    xy=(-0.5, 0),  # Coordenada inferior esquerda (x, y)
    width=3,  # Largura do retângulo (destaca os 3 primeiros)
    height=max(df_mortes['mortos']) * 1.05,  # Ajuste automático na altura
    linewidth=2,  # Espessura da linha
    edgecolor='red',  # Cor do contorno
    facecolor='none'  # Sem preenchimento interno
)
ax.add_patch(rect)

# Adicionar anotação
ax.annotate(
    xy=(2.5, max(df_mortes['mortos']) * 0.9),
    text="Os 3 estados com mais mortes são \nMinas Gerais, Paraná e Bahia",
    arrowprops=dict(facecolor='red', edgecolor='red', shrink=0.05),
    xytext=(5, max(df_mortes['mortos']) * 0.85)
)

fig.show()
# Out:
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\2109064236.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\2109064236.py:34: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

colunas = list(df['causa_acidente'].value_counts().head(5).index)

fig, ax = plt.subplots(1, 2, figsize=(30, 10))

# Criação de df info_ufs com os dados baixados do site do IBGE
info_ufs = gpd.read_file(imagem, layer='lim_unidade_federacao_a')
info_ufs.rename({'sigla': 'uf'}, axis=1, inplace=True)

# df de Mortes por estados
df_mortes = df[['uf', 'mortos']].groupby(by=df['uf']).agg({'mortos': 'sum'}).sort_values(by='mortos', ascending=False)

# Criação de nova df com junção de df_mortes e info_ufs
brasil_mortes = info_ufs.merge(df_mortes, on='uf', how='left')

# Escala de cores de acordo com a quantidade de mortes (gradiente vermelho)
cmap = plt.cm.get_cmap('Reds', len(df_mortes))  # Alterado para 'Reds'

# Criação de gráfico do mapa do brasil
brasil_mortes.plot(column='mortos', cmap=cmap, legend=False, edgecolor='black', ax=ax[0])

centroids = brasil_mortes.geometry.centroid
counts = brasil_mortes['mortos']

for idx, (centroid, count) in enumerate(zip(centroids, counts)):
    ax[0].annotate(f'{count:.0f}', (centroid.x, centroid.y), textcoords="offset points", xytext=(0, -2), ha='center', fontsize=12, color='black')

ax[0].set_title('Morte por estados no Brasil')

# Gráfico de barras
df_top5 = df[df['uf'].isin(['MG', 'PR', 'BA'])][df['causa_acidente'].isin(colunas)]

df_top5_group = df_top5[['uf', 'causa_acidente', 'mortos']].groupby(by=['uf', 'causa_acidente']).sum('mortos').unstack()

df_top5_group = df_top5_group.reindex(['MG', 'PR', 'BA'])

nova_coluna = ['Velocidade Incompatível', 'Falta de Atenção à Condução', 'Desobediência às normas de trânsito pelo condutor', 'Ingestão de Álcool', 'Reação tardia ou ineficiente do condutor']

df_top5_group = df_top5_group['mortos'][nova_coluna].plot(kind='bar', ax=ax[1], color=['#8B0000', '#D72638', '#F46036', '#F3A712', '#3E3E3E'])

ax[1].set_title('Top 5 causas de acidentes nos estados com mais mortes em BRs')
ax[1].set_xlabel('Estados')
ax[1].set_ylabel('Número de mortes')

ax[1].annotate('Velocidade incompatível e Falta de Atenção à Condução se destacam em MG', xy=(-0.15, 1000), xytext=(0, 900),
               arrowprops=dict(facecolor='black', shrink=0.05))

ax[1].annotate('Velocidade incompatível e Falta de Atenção à Condução se destacam em MG', xy=(-0.1, 700), xytext=(0, 900),
               arrowprops=dict(facecolor='black', shrink=0.05))

for i, patch in enumerate(ax[1].patches):
    # Check if it's one of the first two bars of the current state
    if i in ([0, 1, 2, 3, 4, 5]):
        height = patch.get_height()  # Get the height of the bar

        # Calculate the x-coordinate of the label
        x = patch.get_x() + patch.get_width() / 2

        # Add the text label
        ax[1].text(x, height, f'{int(height)}', ha='center', va='bottom')

plt.show()
# Out:
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\3267593086.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Reds', len(df_mortes))  # Alterado para 'Reds'
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\3267593086.py:24: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = brasil_mortes.geometry.centroid
# C:\Users\mirel\AppData\Local\Temp\ipykernel_14664\3267593086.py:33: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_top5 = df[df['uf'].isin(['MG', 'PR', 'BA'])][df['causa_acidente'].isin(colunas)]

# %%
df[['dia_semana','causa_acidente']].value_counts()
# Out:
# dia_semana     causa_acidente
# sexta-feira    Falta de Atenção à Condução                    17134
# sábado         Falta de Atenção à Condução                    16956
# domingo        Falta de Atenção à Condução                    16186
# segunda-feira  Falta de Atenção à Condução                    14954
# quinta-feira   Falta de Atenção à Condução                    14611
#                                                               ...
# quarta-feira   Sinalização encoberta                              1
#                Semáforo com defeito                               1
# domingo        Transtornos Mentais (exceto suicidio)              1
# terça-feira    Faixas de trânsito com largura insuficiente        1
# sexta-feira    Obstrução Via tentativa Assalto                    1
# Name: count, Length: 617, dtype: int64

# %%
df_counts = df.value_counts(["dia_semana", "causa_acidente"]).reset_index(name="quantidade")
df_counts=df_counts[df_counts['causa_acidente'].isin(['Velocidade Incompatível','Falta de Atenção à Condução','Ingestão de Álcool','Desobediência às normas de trânsito pelo condutor','Reação tardia ou ineficiente do condutor'])]
df_counts
# Out:
#         dia_semana                                     causa_acidente  \
# 0      sexta-feira                        Falta de Atenção à Condução
# 1           sábado                        Falta de Atenção à Condução
# 2          domingo                        Falta de Atenção à Condução
# 3    segunda-feira                        Falta de Atenção à Condução
# 4     quinta-feira                        Falta de Atenção à Condução
# 5     quarta-feira                        Falta de Atenção à Condução
# 6      terça-feira                        Falta de Atenção à Condução
# 7          domingo                            Velocidade Incompatível
# 8           sábado                            Velocidade Incompatível
# 9          domingo                                 Ingestão de Álcool
# 10     sexta-feira                            Velocidade Incompatível
# 11          sábado                                 Ingestão de Álcool
# 12   segunda-feira                            Velocidade Incompatível
# 13    quinta-feira                            Velocidade Incompatível
# 14     terça-feira                            Velocidade Incompatível
# 15    quarta-feira                            Velocidade Incompatível
# 16          sábado  Desobediência às normas de trânsito pelo condutor
# 17     sexta-feira  Desobediência às normas de trânsito pelo condutor
# 18         domingo  Desobediência às normas de trânsito pelo condutor
# 19    quinta-feira  Desobediência às normas de trânsito pelo condutor
# 20   segunda-feira  Desobediência às normas de trânsito pelo condutor
# 21     terça-feira  Desobediência às normas de trânsito pelo condutor
# 22    quarta-feira  Desobediência às normas de trânsito pelo condutor
# 23         domingo           Reação tardia ou ineficiente do condutor
# 25          sábado           Reação tardia ou ineficiente do condutor
# 28     sexta-feira           Reação tardia ou ineficiente do condutor
# 32   segunda-feira           Reação tardia ou ineficiente do condutor
# 35    quinta-feira           Reação tardia ou ineficiente do condutor
# 36    quarta-feira           Reação tardia ou ineficiente do condutor
# 38     terça-feira           Reação tardia ou ineficiente do condutor
# 39     sexta-feira                                 Ingestão de Álcool
# 73   segunda-feira                                 Ingestão de Álcool
# 76    quinta-feira                                 Ingestão de Álcool
# 92    quarta-feira                                 Ingestão de Álcool
# 104    terça-feira                                 Ingestão de Álcool
#
#      quantidade
# 0         17134
# 1         16956
# 2         16186
# 3         14954
# 4         14611
# 5         14178
# 6         13769
# 7          8349
# 8          7878
# 9          7027
# 10         6390
# 11         6018
# 12         5777
# 13         5345
# 14         5027
# 15         4956
# 16         4832
# 17         4725
# 18         4203
# 19         4014
# 20         4003
# 21         3775
# 22         3767
# 23         3696
# 25         3547
# 28         3276
# 32         2985
# 35         2786
# 36         2757
# 38         2682
# 39         2664
# 73         1895
# 76         1784
# 92         1449
# 104        1304

# %%
fig = px.bar(df_counts,
             y="dia_semana",
             x="quantidade",
             color="causa_acidente",
             barmode="stack",
             orientation="h",
             title='Causa de acidentes por dia da semana',
             category_orders={'dia_semana': ['segunda-feira', 'terça-feira', 'quarta-feira', 'quinta-feira', 'sexta-feira', 'sábado', 'domingo']},
             text_auto=True,
             color_discrete_map={
                 "Falta de Atenção à Condução": "#8B0000",
                 "Velocidade Incompatível": "#D72638",
                 "Ingestão de Álcool": "#F46036",
                 "Desobediência às normas de trânsito pelo condutor": "#F3A712",
                 "Reação tardia ou ineficiente do condutor": "#3E3E3E"
             }  # Substitua pelos nomes corretos das causas
            )

fig.add_annotation(
    x=40000,  # Valor no eixo X onde a anotação será colocada
    y="sexta-feira",  # Dia da semana no eixo Y
    text="Aumento de acidentes por Ingestão de alcool <br> e Velocidade incompatível no final de semana",  # Texto da anotação
    showarrow=True,  # Exibir uma seta
    arrowhead=3,  # Tipo da seta
    ax=50,  # Deslocamento horizontal da seta
    ay=0,  # Deslocamento vertical da seta
    bgcolor="red",  # Cor de fundo da anotação
    font=dict(color="white", size=12)  # Cor e tamanho do texto
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 31
#       1 fig = px.bar(df_counts,
#       2              y="dia_semana",
#       3              x="quantidade",
#    (...)
#      16              }  # Substitua pelos nomes corretos das causas
#      17             )
#      19 # fig.add_annotation(
#      20 #     x=40000,  # Valor no eixo X onde a anotação será colocada
#      21 #     y="sexta-feira",  # Dia da semana no eixo Y
#    (...)
#      28 #     font=dict(color="white", size=12)  # Cor e tamanho do texto
#      29 # )
# ---> 31 fig.show()
#
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# ## Insight 2 - Mais acidentes próximo a datas de feriados em Pernambuco

# %%
df_pe['ano']=df['data_acidente'].dt.year
df_pe
# Out:
# C:\Users\mirel\AppData\Local\Temp\ipykernel_21388\2536732588.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            dia_semana   horario  uf     br     km    municipio  \
# 15            domingo  15:55:00  PE  101.0   62.8       RECIFE
# 24            domingo  22:00:00  PE  232.0  142.0  SAO CAITANO
# 25            domingo  21:30:00  PE  232.0   84.7      GRAVATA
# 34      segunda-feira  06:30:00  PE  101.0   23.0       GOIANA
# 51      segunda-feira  13:50:00  PE  101.0   73.2       RECIFE
# ...               ...       ...  ..    ...    ...          ...
# 462858   quarta-feira  18:00:00  PE  104.0  113.0      PANELAS
# 462871   quarta-feira  20:07:00  PE  104.0   61.0      CARUARU
# 462936         sábado  15:30:00  PE  104.0   62.0      CARUARU
# 462963   quinta-feira  16:40:00  PE  104.0   61.0      CARUARU
# 462977   quinta-feira  18:00:00  PE  423.0   98.2    GARANHUNS
#
#                                            causa_acidente  \
# 15                           Falta de Atenção do Pedestre
# 24                            Falta de Atenção à Condução
# 25                                       Animais na Pista
# 34                            Falta de Atenção à Condução
# 51                            Falta de Atenção à Condução
# ...                                                   ...
# 462858                                   Pista esburacada
# 462871  Acessar a via sem observar a presença dos outr...
# 462936                        Manobra de mudança de faixa
# 462963                        Manobra de mudança de faixa
# 462977                     Ausência de reação do condutor
#
#                         tipo_acidente classificacao_acidente     fase_dia  \
# 15          Atropelamento de Pedestre    Com Vítimas Feridas    Pleno dia
# 24                    Colisão lateral            Sem Vítimas  Plena Noite
# 25            Atropelamento de Animal            Sem Vítimas  Plena Noite
# 34                   Colisão traseira            Sem Vítimas    Pleno dia
# 51                    Colisão lateral            Sem Vítimas    Pleno dia
# ...                               ...                    ...          ...
# 462858   Queda de ocupante de veículo    Com Vítimas Feridas  Plena Noite
# 462871            Colisão transversal    Com Vítimas Feridas  Plena Noite
# 462936               Colisão traseira    Com Vítimas Feridas    Pleno dia
# 462963  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
# 462977      Saída de leito carroçável    Com Vítimas Feridas  Plena Noite
#
#         ... feridos_leves feridos_graves ilesos ignorados  feridos  veiculos  \
# 15      ...             0              1      1         1        1         1
# 24      ...             0              0      2         0        0         2
# 25      ...             0              0      1         0        0         1
# 34      ...             0              0      2         0        0         2
# 51      ...             0              0      3         0        0         2
# ...     ...           ...            ...    ...       ...      ...       ...
# 462858  ...             0              1      0         0        1         1
# 462871  ...             2              0      1         0        2         2
# 462936  ...             0              1      1         0        1         2
# 462963  ...             3              0      0         0        3         2
# 462977  ...             2              1      0         0        3         1
#
#         latitude  longitude       data_acidente   ano
# 15     -8.007427  -34.93785 2017-01-01 15:55:00  2017
# 24     -8.326607  -36.11564 2017-01-01 22:00:00  2017
# 25     -8.215031  -35.63572 2017-01-01 21:30:00  2017
# 34     -7.684500  -34.92370 2017-01-02 06:30:00  2017
# 51     -8.096529  -34.94960 2017-01-02 13:50:00  2017
# ...          ...        ...                 ...   ...
# 462858 -8.643015  -36.01540 2023-08-30 18:00:00  2023
# 462871 -8.245830  -35.97492 2023-08-30 20:07:00  2023
# 462936 -8.261800  -35.97600 2023-07-29 15:30:00  2023
# 462963 -8.252900  -35.97510 2023-08-31 16:40:00  2023
# 462977 -8.875224  -36.50594 2023-08-31 18:00:00  2023
#
# [18671 rows x 26 columns]

# %%
df_pe_2022=df_pe[df_pe['ano']==2022][['data_acidente','mortos']].groupby('data_acidente').agg({'mortos':'sum'})
df_pe_2022[df_pe_2022['mortos']>3]
# Out:
#                      mortos
# data_acidente
# 2022-12-10 03:30:00       5
# 2022-12-31 04:30:00       5

# %%
fig, ax = plt.subplots(2,1,figsize=(30,15))

plt.suptitle('Análise temporal das mortes em Pernambuco no ano de 2022', size=16)
#Mortes por mês em 2022

data=df_pe_2022.reset_index()
data['data_acidente']=pd.to_datetime(data['data_acidente'], format = '%d-%m-%Y')
data.groupby(data['data_acidente'].dt.month).agg({'mortos':'sum'}).plot(ax=ax[0], color='#D72638', linewidth=2)
ax[0].text(1,36,'Segundo semestre apresentou o maior número de mortes nas BRs Pernambucanas em 2022.', size=12)
ax[0].text(1,35,'Top 3 meses com mais mortes em 2022: Dezembro, Outubro e Maio .', size=12)
ax[0].set_title('Mortes por Mês em Pernambuco no ano de 2022', size=15)
ax[0].set_xlabel('Mês', size=12)

#Mortes por dia do Ano
df_pe_2022=df_pe[df_pe['ano']==2022][['data_acidente','mortos']].groupby('data_acidente').agg({'mortos':'sum'})

df_pe_2022.index=df_pe_2022.index.astype('datetime64[ns]')

sns.lineplot(data=df_pe_2022, x=df_pe_2022.index, y='mortos', ax=ax[1], color='#D72638', linewidth=2)



datas_anotacoes = ['2022-05-06', '2022-06-05', '2022-10-12','2022-11-06','2022-01-16','2022-12-22','2022-12-26','2022-12-31']

ax[1].annotate(text='Domingo - 16/01',xy=(pd.to_datetime('2022-01-16'), df_pe_2022.loc[pd.to_datetime('2022-01-16'), 'mortos']),  # Coordenadas do ponto
                xytext=(0, 10),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)


ax[1].annotate(text='Sexta-Feira 06/05',xy=(pd.to_datetime('2022-05-06'), df_pe_2022.loc[pd.to_datetime('2022-05-06'), 'mortos']),  # Coordenadas do ponto
                xytext=(0, 30),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)


ax[1].annotate(text='Domingo 05/06',xy=(pd.to_datetime('2022-06-05'), df_pe_2022.loc[pd.to_datetime('2022-06-05'), 'mortos']),  # Coordenadas do ponto
                xytext=(0, 10),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)


ax[1].annotate(text='12/10 - Dia de Nossa Senhora aparecida',xy=(pd.to_datetime('2022-10-12'), df_pe_2022.loc[pd.to_datetime('2022-10-12'), 'mortos']),  # Coordenadas do ponto
                xytext=(-30, 10),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)


ax[1].annotate(text='06/11 - Volta do feriado de Finados',xy=(pd.to_datetime('2022-11-06'), df_pe_2022.loc[pd.to_datetime('2022-11-06'), 'mortos']),  # Coordenadas do ponto
                xytext=(0, 50),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)


ax[1].annotate(text='22/12 - Quinta-Feira próxima ao Natal',xy=(pd.to_datetime('2022-12-22'), df_pe_2022.loc[pd.to_datetime('2022-12-22'), 'mortos']),  # Coordenadas do ponto
                xytext=(-50, 70),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)

ax[1].annotate(text='26/12 - Segunda-Feira após Natal',xy=(pd.to_datetime('2022-12-26'), df_pe_2022.loc[pd.to_datetime('2022-12-26'), 'mortos']),  # Coordenadas do ponto
                xytext=(60, 30),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)

ax[1].annotate(text='31/12 - Véspera de Ano novo',xy=(pd.to_datetime('2022-12-31'), df_pe_2022.loc[pd.to_datetime('2022-12-31'), 'mortos']),  # Coordenadas do ponto
                xytext=(0, 10),  # Deslocamento do texto
                textcoords="offset points",  # Sistema de coordenadas para xytext
                ha='center',  # Alinhamento horizontal do texto
                arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)

ax[1].text(x=pd.to_datetime('2022-06-01'), y= 7, s='Maioria dos acidentes fatais do segundo semestre aconteceram em épocas de feriados', size=12)
ax[1].set_title('Mortes por dia em Pernambuco no ano de 2022', size=15)


ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[0].spines['left'].set_visible(False)


ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['left'].set_visible(False)


ax[0].tick_params(axis='both', which='major', labelsize=12)
ax[1].tick_params(axis='both', which='major', labelsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1642291200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2022-01-16 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\datetimes.py:630, in DatetimeIndex.get_loc(self, key)
#     629 try:
# --> 630     return Index.get_loc(self, key)
#     631 except KeyError as err:
#
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: Timestamp('2022-01-16 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 25
#      19 sns.lineplot(data=df_pe_2022, x=df_pe_2022.index, y='mortos', ax=ax[1], color='#D72638', linewidth=2)
#      23 datas_anotacoes = ['2022-05-06', '2022-06-05', '2022-10-12','2022-11-06','2022-01-16','2022-12-22','2022-12-26','2022-12-31']
# ---> 25 ax[1].annotate(text='Domingo - 16/01',xy=(pd.to_datetime('2022-01-16'), df_pe_2022.loc[pd.to_datetime('2022-01-16'), 'mortos']),  # Coordenadas do ponto
#      26                 xytext=(0, 10),  # Deslocamento do texto
#      27                 textcoords="offset points",  # Sistema de coordenadas para xytext
#      28                 ha='center',  # Alinhamento horizontal do texto
#      29                 arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)
#      32 ax[1].annotate(text='Sexta-Feira 06/05',xy=(pd.to_datetime('2022-05-06'), df_pe_2022.loc[pd.to_datetime('2022-05-06'), 'mortos']),  # Coordenadas do ponto
#      33                 xytext=(0, 30),  # Deslocamento do texto
#      34                 textcoords="offset points",  # Sistema de coordenadas para xytext
#      35                 ha='center',  # Alinhamento horizontal do texto
#      36                 arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)
#      39 ax[1].annotate(text='Domingo 05/06',xy=(pd.to_datetime('2022-06-05'), df_pe_2022.loc[pd.to_datetime('2022-06-05'), 'mortos']),  # Coordenadas do ponto
#      40                 xytext=(0, 10),  # Deslocamento do texto
#      41                 textcoords="offset points",  # Sistema de coordenadas para xytext
#      42                 ha='center',  # Alinhamento horizontal do texto
#      43                 arrowprops=dict(arrowstyle="->"), size=12)  # Estilo da seta (opcional)
#
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
# -> 4221     row = self.index.get_loc(index)
#    4222     return series._values[row]
#    4224 # For MultiIndex going through engine effectively restricts us to
#    4225 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File c:\Users\mirel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\datetimes.py:632, in DatetimeIndex.get_loc(self, key)
#     630     return Index.get_loc(self, key)
#     631 except KeyError as err:
# --> 632     raise KeyError(orig_key) from err
#
# KeyError: Timestamp('2022-01-16 00:00:00')

# %% [markdown]
# ## Insight 3 - Taxa de Acidentalidade e de Mortalidade por Acidentes por ano por estado

# %%
df['uf'].sort_values().unique()
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
estados2=df[['uf','mortos','data_acidente']].groupby([df['uf'],df['data_acidente'].dt.year]).agg({'uf':'count','mortos':'sum'}).unstack()
estados2['Media_acidentes']=np.mean(estados2['uf'], axis=1)
estados2['Media_mortes']=np.mean(estados2['mortos'], axis=1)
estados2
# Out:
#                   uf                                     mortos            \
# data_acidente   2017  2018  2019  2020  2021  2022  2023   2017 2018 2019
# uf
# AC               304   238   262   300   255   224   145     18   26   24
# AL               904   691   630   628   580   595   399    102   91   98
# AM               131   124   102   138    93   112    72     14   17   18
# AP               166   173   128   155   170   180    94      9   15   16
# BA              4687  3559  3487  3461  3313  3440  2391    594  456  477
# CE              1954  1697  1694  1572  1543  1373   893    190  180  157
# DF              1093   867  1091  1040   981   922   648     46   44   52
# ES              3004  2642  2846  2534  2525  2278  1479    201  133  147
# GO              4369  3465  3358  3228  3189  3111  2026    344  282  276
# MA              1583  1274  1079  1154  1131  1084   744    246  232  197
# MG             12730  9073  8736  8375  8327  8290  5790    869  693  679
# MS              1933  1530  1436  1542  1642  1638  1141    162  109  124
# MT              3526  2632  2139  2195  2138  2175  1467    191  229  226
# PA              1504  1260   823   963   844   831   573    162  143  137
# PB              1852  1589  1565  1401  1440  1474  1004    139  133  130
# PE              3441  2716  2739  2562  2555  2746  1916    343  296  308
# PI              1540  1371  1347  1205  1139  1114   806    209  159  149
# PR             10689  7958  7722  7199  7342  7377  4646    612  494  500
# RJ              5971  4577  4616  4238  4565  4703  3561    341  276  354
# RN              1457  1417  1442  1339  1340  1287   863    139  118   90
# RO              1831  1630  1536  1486  1419  1378   963    119   91   89
# RR               286   236   237   250   268   229    95     37   22   38
# RS              6386  4449  4598  4177  4538  4928  3331    391  314  304
# SC             10664  8499  8432  7221  7889  7589  5122    381  387  403
# SE               763   559   612   575   511   511   340     52   41   62
# SP              6011  4517  4379  4043  4300  4385  3110    255  207  204
# TO               785   589   520   595   501   568   416     82   85   79
#
#                                   Media_acidentes Media_mortes
# data_acidente 2020 2021 2022 2023
# uf
# AC              13   22   18   16      246.857143    19.571429
# AL              82   91   54   43      632.428571    80.142857
# AM              16    9   19    6      110.285714    14.142857
# AP               5   12   20    9      152.285714    12.285714
# BA             507  500  528  364     3476.857143   489.428571
# CE             176  184  148   90     1532.285714   160.714286
# DF              39   33   44   39      948.857143    42.428571
# ES             142  148  154  114     2472.571429   148.428571
# GO             271  303  291  178     3249.428571   277.857143
# MA             244  217  211  152     1149.857143   214.142857
# MG             717  693  701  477     8760.142857   689.857143
# MS             139  143  167  124     1551.714286   138.285714
# MT             232  223  263  183     2324.571429   221.000000
# PA             123  164  183  123      971.142857   147.857143
# PB             103  109  129   84     1475.000000   118.142857
# PE             318  308  305  192     2667.857143   295.714286
# PI             160  130  137   96     1217.428571   148.571429
# PR             527  570  571  371     7561.857143   520.714286
# RJ             272  308  257  214     4604.428571   288.857143
# RN             100  101   94   61     1306.428571   100.428571
# RO              82   85   86   69     1463.285714    88.714286
# RR              27   28   24   16      228.714286    27.428571
# RS             236  316  334  222     4629.571429   302.428571
# SC             382  357  350  248     7916.571429   358.285714
# SE              42   39   47   25      553.000000    44.000000
# SP             240  220  223  151     4392.142857   214.285714
# TO              98   83   81   44      567.714286    78.857143

# %%
estados3 = estados2[['Media_acidentes','Media_mortes']]
estados3.reset_index()
# Out:
#                uf Media_acidentes Media_mortes
# data_acidente
# 0              AC      246.857143    19.571429
# 1              AL      632.428571    80.142857
# 2              AM      110.285714    14.142857
# 3              AP      152.285714    12.285714
# 4              BA     3476.857143   489.428571
# 5              CE     1532.285714   160.714286
# 6              DF      948.857143    42.428571
# 7              ES     2472.571429   148.428571
# 8              GO     3249.428571   277.857143
# 9              MA     1149.857143   214.142857
# 10             MG     8760.142857   689.857143
# 11             MS     1551.714286   138.285714
# 12             MT     2324.571429   221.000000
# 13             PA      971.142857   147.857143
# 14             PB     1475.000000   118.142857
# 15             PE     2667.857143   295.714286
# 16             PI     1217.428571   148.571429
# 17             PR     7561.857143   520.714286
# 18             RJ     4604.428571   288.857143
# 19             RN     1306.428571   100.428571
# 20             RO     1463.285714    88.714286
# 21             RR      228.714286    27.428571
# 22             RS     4629.571429   302.428571
# 23             SC     7916.571429   358.285714
# 24             SE      553.000000    44.000000
# 25             SP     4392.142857   214.285714
# 26             TO      567.714286    78.857143

# %%
estados = estados2[['Media_acidentes','Media_mortes']]
estados=estados.reset_index()
estados
# Out:
#                uf Media_acidentes Media_mortes
# data_acidente
# 0              AC      246.857143    19.571429
# 1              AL      632.428571    80.142857
# 2              AM      110.285714    14.142857
# 3              AP      152.285714    12.285714
# 4              BA     3476.857143   489.428571
# 5              CE     1532.285714   160.714286
# 6              DF      948.857143    42.428571
# 7              ES     2472.571429   148.428571
# 8              GO     3249.428571   277.857143
# 9              MA     1149.857143   214.142857
# 10             MG     8760.142857   689.857143
# 11             MS     1551.714286   138.285714
# 12             MT     2324.571429   221.000000
# 13             PA      971.142857   147.857143
# 14             PB     1475.000000   118.142857
# 15             PE     2667.857143   295.714286
# 16             PI     1217.428571   148.571429
# 17             PR     7561.857143   520.714286
# 18             RJ     4604.428571   288.857143
# 19             RN     1306.428571   100.428571
# 20             RO     1463.285714    88.714286
# 21             RR      228.714286    27.428571
# 22             RS     4629.571429   302.428571
# 23             SC     7916.571429   358.285714
# 24             SE      553.000000    44.000000
# 25             SP     4392.142857   214.285714
# 26             TO      567.714286    78.857143

# %%
# Tamanho da populacao de cada estado
populacao = {
    "SP": 45973194, "MG": 21322691, "RJ": 17219679, "BA": 14850513, "PR": 11824665,
    "RS": 11229915, "PE": 9539029, "CE": 9233656, "PA": 8664306, "SC": 8058441,
    "GO": 7350483, "MA": 7010960, "AM": 4281209, "PB": 4145040, "ES": 4102129,
    "MT": 3836399, "RN": 3446071, "PI": 3375646, "AL": 3220104, "DF": 2982818,
    "MS": 2901895, "SE": 2291077, "RO": 1746227, "TO": 1577342, "AC": 880631,
    "AP": 802837, "RR": 716793
}

estados['Populacao'] = estados["uf"].map(populacao)
estados
# Out:
#                uf Media_acidentes Media_mortes Populacao
# data_acidente
# 0              AC      246.857143    19.571429    880631
# 1              AL      632.428571    80.142857   3220104
# 2              AM      110.285714    14.142857   4281209
# 3              AP      152.285714    12.285714    802837
# 4              BA     3476.857143   489.428571  14850513
# 5              CE     1532.285714   160.714286   9233656
# 6              DF      948.857143    42.428571   2982818
# 7              ES     2472.571429   148.428571   4102129
# 8              GO     3249.428571   277.857143   7350483
# 9              MA     1149.857143   214.142857   7010960
# 10             MG     8760.142857   689.857143  21322691
# 11             MS     1551.714286   138.285714   2901895
# 12             MT     2324.571429   221.000000   3836399
# 13             PA      971.142857   147.857143   8664306
# 14             PB     1475.000000   118.142857   4145040
# 15             PE     2667.857143   295.714286   9539029
# 16             PI     1217.428571   148.571429   3375646
# 17             PR     7561.857143   520.714286  11824665
# 18             RJ     4604.428571   288.857143  17219679
# 19             RN     1306.428571   100.428571   3446071
# 20             RO     1463.285714    88.714286   1746227
# 21             RR      228.714286    27.428571    716793
# 22             RS     4629.571429   302.428571  11229915
# 23             SC     7916.571429   358.285714   8058441
# 24             SE      553.000000    44.000000   2291077
# 25             SP     4392.142857   214.285714  45973194
# 26             TO      567.714286    78.857143   1577342

# %%
estados['Acidentes_por_1k_habitantes'] = estados['Media_acidentes'] / estados['Populacao'] * 1000
estados['Mortes_por_1k_habitantes'] = estados['Media_mortes'] / estados['Populacao'] * 1000
estados
# Out:
#                uf Media_acidentes Media_mortes Populacao  \
# data_acidente
# 0              AC      246.857143    19.571429    880631
# 1              AL      632.428571    80.142857   3220104
# 2              AM      110.285714    14.142857   4281209
# 3              AP      152.285714    12.285714    802837
# 4              BA     3476.857143   489.428571  14850513
# 5              CE     1532.285714   160.714286   9233656
# 6              DF      948.857143    42.428571   2982818
# 7              ES     2472.571429   148.428571   4102129
# 8              GO     3249.428571   277.857143   7350483
# 9              MA     1149.857143   214.142857   7010960
# 10             MG     8760.142857   689.857143  21322691
# 11             MS     1551.714286   138.285714   2901895
# 12             MT     2324.571429   221.000000   3836399
# 13             PA      971.142857   147.857143   8664306
# 14             PB     1475.000000   118.142857   4145040
# 15             PE     2667.857143   295.714286   9539029
# 16             PI     1217.428571   148.571429   3375646
# 17             PR     7561.857143   520.714286  11824665
# 18             RJ     4604.428571   288.857143  17219679
# 19             RN     1306.428571   100.428571   3446071
# 20             RO     1463.285714    88.714286   1746227
# 21             RR      228.714286    27.428571    716793
# 22             RS     4629.571429   302.428571  11229915
# 23             SC     7916.571429   358.285714   8058441
# 24             SE      553.000000    44.000000   2291077
# 25             SP     4392.142857   214.285714  45973194
# 26             TO      567.714286    78.857143   1577342
#
#               Acidentes_por_1k_habitantes Mortes_por_1k_habitantes
# data_acidente
# 0                                0.280318                 0.022224
# 1                                0.196400                 0.024888
# 2                                0.025760                 0.003303
# 3                                0.189684                 0.015303
# 4                                0.234124                 0.032957
# 5                                0.165946                 0.017405
# 6                                0.318108                 0.014224
# 7                                0.602753                 0.036183
# 8                                0.442070                 0.037801
# 9                                0.164009                 0.030544
# 10                               0.410837                 0.032353
# 11                               0.534724                 0.047654
# 12                               0.605925                 0.057606
# 13                               0.112085                 0.017065
# 14                               0.355847                 0.028502
# 15                               0.279678                 0.031000
# 16                               0.360651                 0.044013
# 17                               0.639499                 0.044036
# 18                               0.267393                 0.016775
# 19                               0.379107                 0.029143
# 20                               0.837970                 0.050803
# 21                               0.319080                 0.038266
# 22                               0.412253                 0.026931
# 23                               0.982395                 0.044461
# 24                               0.241371                 0.019205
# 25                               0.095537                 0.004661
# 26                               0.359918                 0.049994

# %%
# Criar a figura e os eixos
fig, ax1 = plt.subplots(figsize=(15, 8))
ax2 = ax1.twinx()

# Plotando os acidentes por habitante no primeiro eixo (ax1)
ax1.plot(estados["uf"], estados["Acidentes_por_1k_habitantes"], marker='o', color='#3E3E3E', label="Acidentes por 1k Habitante")

# Plotando as mortes por habitante no segundo eixo (ax2)
ax2.plot(estados["uf"], estados["Mortes_por_1k_habitantes"], marker='s', color='#D72638', linestyle="dashed", label="Mortes por 1k Habitante")

# Configurações do eixo 1 (Acidentes)
ax1.set_xlabel("Estado (UF)")
ax1.set_ylabel("Acidentes por 1k Habitantes", color='#3E3E3E')
ax1.tick_params(axis='y', labelcolor='#3E3E3E')

# Configurações do eixo 2 (Mortes)
ax2.set_ylabel("Mortes por 1k Habitantes", color='#D72638')
ax2.tick_params(axis='y', labelcolor='#D72638')

# Título e legendas
ax1.set_title("Acidentes e Mortes por 1k Habitante por Estado", loc="left")
fig.tight_layout()

n = 3

# Encontrar os 'n' maiores e menores valores
top_n_acidentes = estados.nlargest(n, "Acidentes_por_1k_habitantes")
bottom_n_acidentes = estados.nsmallest(n, "Acidentes_por_1k_habitantes")

top_n_mortes = estados.nlargest(n, "Mortes_por_1k_habitantes")
bottom_n_mortes = estados.nsmallest(n, "Mortes_por_1k_habitantes")

# Adicionando rótulos apenas nos pontos mais altos e mais baixos
for x, y in zip(top_n_acidentes.index, top_n_acidentes["Acidentes_por_1k_habitantes"]):
    ax1.annotate(f'{y:.6f}', xy=(x, y), xytext=(0, 5), textcoords='offset points', ha='center', fontsize=8, color='#3E3E3E')

for x, y in zip(bottom_n_acidentes.index, bottom_n_acidentes["Acidentes_por_1k_habitantes"]):
    ax1.annotate(f'{y:.6f}', xy=(x, y), xytext=(0, 5), textcoords='offset points', ha='center', fontsize=8, color='#3E3E3E')

for x, y in zip(top_n_mortes.index, top_n_mortes["Mortes_por_1k_habitantes"]):
    ax2.annotate(f'{y:.6f}', xy=(x, y), xytext=(0, 5), textcoords='offset points', ha='center', fontsize=8, color='#D72638')

for x, y in zip(bottom_n_mortes.index, bottom_n_mortes["Mortes_por_1k_habitantes"]):
    ax2.annotate(f'{y:.6f}', xy=(x, y), xytext=(0, -10), textcoords='offset points', ha='center', fontsize=8, color='#D72638')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(2, 1, figsize=(15, 8))

# Plotando os acidentes por habitante no primeiro eixo (ax[0])
ax[0].plot(estados["uf"], estados["Acidentes_por_1k_habitantes"], marker='o', color='#3E3E3E', label="Acidentes por 1k Habitante")

# Plotando as mortes por habitante no segundo eixo (ax[1])
ax[1].plot(estados["uf"], estados["Mortes_por_1k_habitantes"], marker='s', color='#D72638', linestyle="dashed", label="Mortes por 1k Habitante")

# Configurações do eixo 1 (Acidentes)
ax[0].set_xlabel("Estado (UF)")
ax[0].set_ylabel("Acidentes por 1k Habitantes", color='#3E3E3E')
ax[0].tick_params(axis='y', labelcolor='#3E3E3E')

# Adicionar linhas horizontais nos eixos Y
ax[0].axhline(y=estados["Acidentes_por_1k_habitantes"].mean(), color='#3E3E3E', linestyle='--', linewidth=1, alpha=0.7, label="Média Acidentes")
ax[1].axhline(y=estados["Mortes_por_1k_habitantes"].mean(), color='#D72638', linestyle='--', linewidth=1, alpha=0.7, label="Média Mortes")

# Configurações do eixo 2 (Mortes)
ax[1].set_ylabel("Mortes por 1k Habitantes", color='#D72638')
ax[1].tick_params(axis='y', labelcolor='#D72638')

# Título e legendas
ax[0].set_title("Taxa anual de acidentalidade em BRs per capita", loc="center")
ax[1].set_title("Taxa anual de mortalidade por acidentes em BRs per capita", loc="center")
fig.tight_layout()

n = 3

# Encontrar os 'n' maiores e menores valores
top_n_acidentes = estados.nlargest(n, "Acidentes_por_1k_habitantes")
bottom_n_acidentes = estados.nsmallest(n, "Acidentes_por_1k_habitantes")

top_n_mortes = estados.nlargest(n, "Mortes_por_1k_habitantes")
bottom_n_mortes = estados.nsmallest(n, "Mortes_por_1k_habitantes")

# Adicionando rótulos apenas nos pontos mais altos e mais baixos
for x, y in zip(top_n_acidentes.index, top_n_acidentes["Acidentes_por_1k_habitantes"]):
    ax[0].annotate(f'{y:.6f}', xy=(x, y), xytext=(0, -20), textcoords='offset points', ha='center', fontsize=8, color='#3E3E3E')

for x, y in zip(bottom_n_acidentes.index, bottom_n_acidentes["Acidentes_por_1k_habitantes"]):
    ax[0].annotate(f'{y:.6f}', xy=(x, y), xytext=(0, 5), textcoords='offset points', ha='center', fontsize=8, color='#3E3E3E')

for x, y in zip(top_n_mortes.index, top_n_mortes["Mortes_por_1k_habitantes"]):
    ax[1].annotate(f'{y:.6f}', xy=(x, y), xytext=(0, -20), textcoords='offset points', ha='center', fontsize=8, color='#D72638')

for x, y in zip(bottom_n_mortes.index, bottom_n_mortes["Mortes_por_1k_habitantes"]):
    ax[1].annotate(f'{y:.6f}', xy=(x, y), xytext=(0, 5), textcoords='offset points', ha='center', fontsize=8, color='#D72638')

ax[0].annotate(
    xy=(15, 0.8),
    text="Os 3 estados com maior taxa anual de acidentalidade são \nSanta Catarina, Rondonia e Paraná",  # Texto da anotação
    ha="center",  # Alinhamento do texto
)

ax[1].annotate(
    xy=(5, 0.05),
    text="Os 3 estados com maior taxa anual de mortalidade por acidentes \nem BRs são Mato Grosso, Rondonia e Tocantins",  # Texto da anotação
    ha="center",  # Alinhamento do texto
)

plt.show()
